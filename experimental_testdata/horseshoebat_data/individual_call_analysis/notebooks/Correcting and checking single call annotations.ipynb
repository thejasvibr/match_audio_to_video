# %%
import os
import pandas as pd
from correct_call_annotations import *

# %%
main_folder ='/home/tbeleyur/Documents/packages_dev/match_audio_to_video/experimental_testdata/horseshoebat_data/individual_call_analysis/'
channels_to_save = [0] # save only first channel
individual_call_annotation_folder = os.path.join(main_folder,'raw_individual_call_annotations')
raw_audio_folder = os.path.join(main_folder,'annotation_audio')
destination_audio_folder = os.path.join(main_folder,'raw_ind_calls')

# %%
def show_annotation_row(annotation_df, search_string):
    for i, each in annotation_df.iterrows():
        if search_string  in each['audio_annotation_file']:
            print(each)

# %%
def show_number_of_valid_call_annotations(df):
    print(sum(~pd.isna(df['call_start_time'])))

# %% [markdown]
# ###  2018-08-16 21:50 - 23:00
#
# #### Notes/Comments on the corrections:
#
# * matching_annotaudio_Aditya_2018-08-16_21502300_36 : only a cf section - nothing more.

# %%
# 2018-08-16 21:50-23:00 matched audio annotations 
annotation_20180816_2150_2300 = os.path.join(individual_call_annotation_folder, 
                                             'Audio annotation_2018-08-16_2150_23_pm.csv')
annots_20180816_2150_2300 = pd.read_csv(annotation_20180816_2150_2300)
annots_20180816_2150_2300.head()
# Out:
#                               audio_annotation_file  start_random_point  \
# 0  matching_annotaudio_Aditya_2018-08-16_21502300_1                0.62
# 1  matching_annotaudio_Aditya_2018-08-16_21502300_2                0.22
# 2  matching_annotaudio_Aditya_2018-08-16_21502300_3                0.92
# 3  matching_annotaudio_Aditya_2018-08-16_21502300_4                0.73
# 4  matching_annotaudio_Aditya_2018-08-16_21502300_5                0.75
#
#    search_start_time(s) Direction  No._of_ms_whole_screen  call_start_time  \
# 0                   NaN         R                     NaN              NaN
# 1                   NaN         R                     NaN              NaN
# 2                   NaN         R                     NaN              NaN
# 3                   NaN         L                     NaN              NaN
# 4                   NaN         L                     NaN              NaN
#
#    call_end_time  SNR(dB RMS)  Silent_period_Start  Silent_period_end  \
# ...

# %%
extract_single_calls_from_annotations(annots_20180816_2150_2300, raw_audio_folder,
                                  save_to=destination_audio_folder+'/2018-08-16_2150-2300',
                                  save_channels=[0])
# Out:
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_21502300_1
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_21502300_2
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_21502300_3
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_21502300_4
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_21502300_5
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_21502300_6
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_21502300_7
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_21502300_8
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_21502300_12
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_21502300_13
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_21502300_14
# ...

# %%
show_number_of_valid_call_annotations(annots_20180816_2150_2300)
# Out:
# 36

# %%
show_annotation_row(annots_20180816_2150_2300, '21502300_111')
# Out:
# audio_annotation_file     matching_annotaudio_Aditya_2018-08-16_21502300...
# start_random_point                                                     0.35
# search_start_time(s)                                                   0.91
# Direction                                                                 L
# No._of_ms_whole_screen                                                   80
# call_start_time                                                       0.097
# call_end_time                                                         0.115
# SNR(dB RMS)                                                           28.84
# Silent_period_Start                                                   0.083
# Silent_period_end                                                     0.093
# Comments                                                                NaN
# Name: 81, dtype: object

# %%
ids_20180816_2150_2300_to_be_corrected = {
    'matching_annotaudio_Aditya_2018-08-16_21502300_24':{'call_end_time':0.061},
    'matching_annotaudio_Aditya_2018-08-16_21502300_32':{'call_start_time':0.762,
                                                         'call_end_time':0.819},
    'matching_annotaudio_Aditya_2018-08-16_21502300_33':{'call_end_time':0.031},
    'matching_annotaudio_Aditya_2018-08-16_21502300_39':{'call_start_time':1.798}
                                          _36,
    'matching_annotaudio_Aditya_2018-08-16_21502300_100':{'call_start_time':0.377,
                                                          'call_end_time':0.401}
    'matching_annotaudio_Aditya_2018-08-16_21502300_110':{'call_end_time':0.115},
    'matching_annotaudio_Aditya_2018-08-16_21502300_111':{'call_end_time':0.116}
                                         }
# Out:
#   File "<ipython-input-9-a5629eef7783>", line 7
#     _36,
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 2018-08-16 23:00-24:00

# %%
# 2018-08-16 23:00-24:00 matched audio annotations 
annotation_20180816_2300_2400 = os.path.join(individual_call_annotation_folder, 
                                             'Audio annotation_2018-08-16_2300.csv')
annots_20180816_23_24 = pd.read_csv(annotation_20180816_2300_2400)
annots_20180816_23_24.head()
# Out:
#                           audio_annotation_file  start_random_point  \
# 0  matching_annotaudio_Aditya_2018-08-16_2324_1                0.40
# 1  matching_annotaudio_Aditya_2018-08-16_2324_3                0.13
# 2  matching_annotaudio_Aditya_2018-08-16_2324_4                0.35
# 3  matching_annotaudio_Aditya_2018-08-16_2324_5                0.80
# 4  matching_annotaudio_Aditya_2018-08-16_2324_6                0.20
#
#    search_start_time(s) Direction  No._of_ms_whole_screen  call_start_time  \
# 0                   NaN         L                     NaN              NaN
# 1                0.2132         R                     NaN              NaN
# 2                   NaN         L                     NaN              NaN
# 3                0.4800         R                     NaN              NaN
# 4                   NaN         L                     NaN              NaN
#
#    call_end_time  SNR(dB RMS)  Silent_period_Start  Silent_period_end  \
# ...

# %%
extract_single_calls_from_annotations(annots_20180816_23_24, raw_audio_folder,
                                  save_to=destination_audio_folder+'/2018-08-16_2300-2400/',
                                  save_channels=[0])
# Out:
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_2324_1
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_2324_3
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_2324_4
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_2324_5
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_2324_6
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_2324_8
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_2324_9
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_2324_11
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_2324_12
# Match found!
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_2324_16
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-16_2324_17
# ...

# %% [markdown]
# #### 2018-08-16 23:00-24:00 corrections to be made :
#
# Notes:
#
# * matching_annotaudio_Aditya_2018-08-17_2324_72 :  The original annotation has a start of 2.204 and an end of 2.209. Aditya responded by email on 2020-03-24 saying the end of the annotation should be 2.229.
#
# * matching_annotaudio_Aditya_2018-08-17_2324_92 : no call in it - more like two call fragments.

# %%
ids_20180816_2300_2400_to_be_corrected = {
    'matching_annotaudio_Aditya_2018-08-17_2324_14' : {'call_start_time':0.023},
    'matching_annotaudio_Aditya_2018-08-17_2324_20' : {'call_start_time':0.321, 'call_end_time':0.343},
    'matching_annotaudio_Aditya_2018-08-17_2324_28' : {'call_start_time':0.539, 'call_end_time':0.557},
    'matching_annotaudio_Aditya_2018-08-17_2324_29' : {'call_end_time':0.237},
    'matching_annotaudio_Aditya_2018-08-17_2324_41' : {'call_start_time':0.004, 'call_end_time':0.023},
    'matching_annotaudio_Aditya_2018-08-17_2324_72' : {'call_end_time':2.229},
    92_,
    'matching_annotaudio_Aditya_2018-08-17_2324_72' : {'call_end_time':0.349},
    'matching_annotaudio_Aditya_2018-08-17_2324_154' : {'call_end_time':0.148},
    'matching_annotaudio_Aditya_2018-08-17_2324_156' : {'call_start_time':0.134, 'call_end_time':0.161},
    'matching_annotaudio_Aditya_2018-08-17_2324_171' : {'call_end_time':0.640},
    'matching_annotaudio_Aditya_2018-08-17_2324_196' : {'call_end_time':0.679},
    'matching_annotaudio_Aditya_2018-08-17_2324_198' : {'call_start_time':0.999, 'call_end_time':1.043},
    'matching_annotaudio_Aditya_2018-08-17_2324_207' : {'call_end_time':0.365},
    'matching_annotaudio_Aditya_2018-08-17_2324_223' : {'call_end_time':0.327},
    'matching_annotaudio_Aditya_2018-08-17_2324_248' : {'call_end_time':0.915},
    'matching_annotaudio_Aditya_2018-08-17_2324_253' : {'call_end_time':0.028},
    'matching_annotaudio_Aditya_2018-08-17_2324_255' : {'call_start_time':0.412},
    'matching_annotaudio_Aditya_2018-08-17_2324_258' : {'call_start_time':0.414},
    'matching_annotaudio_Aditya_2018-08-17_2324_277' : {'call_end_time':0.319},
    'matching_annotaudio_Aditya_2018-08-17_2324_288' : {'call_end_time':7.884}    
    }
# Out:
#   File "<ipython-input-12-0bfdb42a385f>", line 8
#     92_,
#       ^
# SyntaxError: invalid syntax

# %%
show_annotation_row(annots_20180816_23_24, '2324_72')
# Out:
# audio_annotation_file         matching_annotaudio_Aditya_2018-08-16_2324_72
# start_random_point                                                     0.62
# search_start_time(s)                                                 3.1744
# Direction                                                                 L
# No._of_ms_whole_screen                                                   45
# call_start_time                                                       2.204
# call_end_time                                                         2.209
# SNR(dB RMS)                                                           36.07
# Silent_period_Start                                                   2.247
# Silent_period_end                                                     2.254
# Comments                  There are 1-2 FM calls in between and 1 HSB at...
# Unnamed: 11                                                             NaN
# Name: 49, dtype: object

# %% [markdown]
# ### -------------------------------------2018-08-17 00:00-01:00-----------------------------------

# %%
# 2018-08-17 00:00-01:00 matched audio annotations 
annotation_20180817_0000_0100 = os.path.join(individual_call_annotation_folder, 
                                             'Audio Annotation Datasheet_2018-08-17_01_am.csv')
annots_20180817_00_01 = pd.read_csv(annotation_20180817_0000_0100)

# %%
extract_single_calls_from_annotations(annots_20180817_00_01, raw_audio_folder,
                                  save_to=destination_audio_folder+'/2018-08-17_0000-0100/',
                                  save_channels=[0])
# Out:
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_01_3
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_01_6
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_01_7
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_01_8
# Match found!
# Match found!
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_01_14
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_01_16
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_01_17
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_01_18
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_01_19
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_01_20
# Match found!
# Match found!
# Match found!
# Could not save call!
# ...

# %% [markdown]
# ### Corrections for 2018-08-17 00:00-01:00
#
# ### Changes to be made:
#
# * __matching_annotaudio_Aditya_2018-08-17_01_11__ : call start time to 0.037, call_end_time to 0.060
# * __matching_annotaudio_Aditya_2018-08-17_01_15__ : call start time 0.370, cal end time to 0.391
# * __matching_annotaudio_Aditya_2018-08-17_01_21__ : call end time to 0.112
# * __matching_annotaudio_Aditya_2018-08-17_01_24__ : *NEEDS TO BE REDONE!!* There's a wrong start and end time. Correction got on 2020-03-21 by email from Aditya. call start time to 0.037, call end time to 0.059
# * __matching_annotaudio_Aditya_2018-08-17_01_26__ : call start time to 0.032, call end time to 0.049
# * __matching_annotaudio_Aditya_2018-08-17_01_28__ : call start time to 0.215
# * __matching_annotaudio_Aditya_2018-08-17_01_29__ : call start time to 0.165
# * __matching_annotaudio_Aditya_2018-08-17_01_34__ : call start time to 0.087, call end time to 0.111
# * __matching_annotaudio_Aditya_2018-08-17_01_35__ : call start time to 0.234, call end time to 0.253
# * __matching_annotaudio_Aditya_2018-08-17_01_36__ : call end time to 1.232
# * __matching_annotaudio_Aditya_2018-08-17_01_37__ : call end time to 0.023
# * __matching_annotaudio_Aditya_2018-08-17_01_43__ : whole call not included in annotation. Call end to 0.740
# * __matching_annotaudio_Aditya_2018-08-17_01_46__ : call start time to 0.505
# * __matching_annotaudio_Aditya_2018-08-17_01_47__ : call end time to 0.921
# * __matching_annotaudio_Aditya_2018-08-17_01_48__ : call end time to 0.086
# * __matching_annotaudio_Aditya_2018-08-17_01_58__ : call start time to 1.094, call end time to 1.141
# * __matching_annotaudio_Aditya_2018-08-17_01_60__ : call start time to 0.027, call end time to 0.050
# * __matching_annotaudio_Aditya_2018-08-17_01_82__ : call start time to 0.648

# %%
ids_20180817_0000_0100_to_be_corrected = {
    'matching_annotaudio_Aditya_2018-08-17_01_82' : {'call_start_time':0.648},
    'matching_annotaudio_Aditya_2018-08-17_01_60' : {'call_start_time':0.027, 'call_end_time':0.050},
    'matching_annotaudio_Aditya_2018-08-17_01_58' : {'call_start_time':1.094, 'call_end_time':1.141},
    'matching_annotaudio_Aditya_2018-08-17_01_48' : {'call_end_time':0.086},
    'matching_annotaudio_Aditya_2018-08-17_01_47' : {'call_end_time':0.921},
    'matching_annotaudio_Aditya_2018-08-17_01_46' : {'call_start_time':0.505},
    'matching_annotaudio_Aditya_2018-08-17_01_43' : {'call_end_time':0.740},
    'matching_annotaudio_Aditya_2018-08-17_01_37' : {'call_end_time':0.023},
    'matching_annotaudio_Aditya_2018-08-17_01_36' : {'call_end_time':1.232},
    'matching_annotaudio_Aditya_2018-08-17_01_35' : {'call_start_time':0.234, 'call_end_time':0.253},
    'matching_annotaudio_Aditya_2018-08-17_01_34' : {'call_start_time':0.087, 'call_end_time':0.111},
    'matching_annotaudio_Aditya_2018-08-17_01_29' : {'call_start_time':0.165},
    'matching_annotaudio_Aditya_2018-08-17_01_28' : {'call_start_time':0.215},
    'matching_annotaudio_Aditya_2018-08-17_01_26' : {'call_start_time':0.032, 'call_end_time':0.049},
    'matching_annotaudio_Aditya_2018-08-17_01_24' : {'call_start_time':0.037, 'call_end_time':0.059},
    'matching_annotaudio_Aditya_2018-08-17_01_21' : {'call_end_time':0.112},
    'matching_annotaudio_Aditya_2018-08-17_01_15' : {'call_start_time':0.370, 'call_end_time':0.391},
    'matching_annotaudio_Aditya_2018-08-17_01_11' : {'call_start_time':0.037, 'call_end_time':0.060}
                    }

# %%
annots_20180817_00_01.head()
# Out:
#                         audio_annotation_file  start_random_point  \
# 0  matching_annotaudio_Aditya_2018-08-17_01_2                0.58
# 1  matching_annotaudio_Aditya_2018-08-17_01_3                0.50
# 2  matching_annotaudio_Aditya_2018-08-17_01_4                0.79
# 3  matching_annotaudio_Aditya_2018-08-17_01_6                0.55
# 4  matching_annotaudio_Aditya_2018-08-17_01_7                0.09
#
#    search_start_time(s) Direction  No._of_ms_whole_screen  call_start_time  \
# 0                0.1392         L                    60.0            0.350
# 1                0.2400         R                     NaN              NaN
# 2                1.2324         R                    50.0            1.257
# 3                0.3300         L                     NaN              NaN
# 4                0.0252         L                     NaN              NaN
#
#    call_end_time  SNR(dB RMS)  Silent_period_Start  Silent_period_end  \
# ...

# %% [markdown]
# ### 2018-08-17 01:00-02:00

# %%
annotation_20180817_0100_0200 = os.path.join(individual_call_annotation_folder, 
                                             'Audio Annotation Datasheet_2018-08-17_01-02_am.csv')
annots_20180817_01_02 = pd.read_csv(annotation_20180817_0100_0200)

# %%
extract_single_calls_from_annotations(annots_20180817_01_02, raw_audio_folder,
                                  save_to=destination_audio_folder+'/2018-08-17_0100-0200/',
                                  save_channels=[0])
# Out:
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_12_3
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_12_6
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_12_7
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_12_9
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_12_12
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_12_13
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_12_14
# Match found!
# Match found!
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_12_23
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_12_24
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_12_25
# Match found!
# Could not save call!
# ...

# %% [markdown]
# ### Corrections for 2018-08-17 01:00-02:00
#
# * __matching_annotaudio_Adity_2018-08-17_12_2__  : call end time to 0.338
# * __matching_annotaudio_Adity_2018-08-17_12_21__ : call start time to 0.718, call end time to 0.770
# * __matching_annotaudio_Adity_2018-08-17_12_39__ : call start time to 0.141, call end time to 0.194
# * __matching_annotaudio_Adity_2018-08-17_12_44__ : call end time to 0.166
# * __matching_annotaudio_Adity_2018-08-17_12_50__ : call end time to 0.228
# * __matching_annotaudio_Aditya_2018-08-17_12_71__: call end time to 1.845
# * __matching_annotaudio_Aditya_2018-08-17_12_76__: call start time to 0.026, call end time to 0.052
# * __matching_annotaudio_Aditya_2018-08-17_12_80__: call start time to 0.080
# * __matching_annotaudio_Aditya_2018-08-17_12_88__: call end time to 0.447
# * __matching_annotaudio_Aditya_2018-08-17_12_104__: call start time to 3.538, call end time to 3.576
# * __matching_annotaudio_Aditya_2018-08-17_12_110__: call start time to 2.345

# %%
ids_20180817_0100_0200_to_be_corrected = {
    'matching_annotaudio_Aditya_2018-08-17_12_2' : {'call_start_time':0.338},
    'matching_annotaudio_Aditya_2018-08-17_12_21' : {'call_start_time':0.718, 'call_end_time': 0.770},
    'matching_annotaudio_Adity_2018-08-17_12_39' : {'call_start_time':0.141, 'call_end_time':0.194},
    'matching_annotaudio_Adity_2018-08-17_12_44' : {'call_end_time':0.166},
    'matching_annotaudio_Adity_2018-08-17_12_50' : {'call_end_time':0.228},
    'matching_annotaudio_Adity_2018-08-17_12_71' : {'call_end_time':1.845},
    'matching_annotaudio_Adity_2018-08-17_12_76' : {'call_start_time':0.026, 'call_end_time':0.052},
    'matching_annotaudio_Adity_2018-08-17_12_80' : {'call_start_time':0.080},
    'matching_annotaudio_Adity_2018-08-17_12_88' : {'call_end_time':0.447},
    'matching_annotaudio_Adity_2018-08-17_12_104' : {'call_start_time':3.538, 'call_end_time':3.576},
    'matching_annotaudio_Adity_2018-08-17_12_110' : {'call_start_time':2.345}
                    }

# %% [markdown]
# ### Corrections for 2018-08-17 02:00-03:00

# %%
annotation_20180817_0200_0300 = os.path.join(individual_call_annotation_folder, 
                                             'Audio Annotation_2018_08_17__23_am.csv')
annots_20180817_02_03 = pd.read_csv(annotation_20180817_0200_0300)

# %%
extract_single_calls_from_annotations(annots_20180817_02_03, raw_audio_folder,
                                  save_to=destination_audio_folder+'/2018-08-17_0200-0300/',
                                  save_channels=[0])
# Out:
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_23_3
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_23_5
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_23_6
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_23_7
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_23_8
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_23_11
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_23_12
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_23_13
# Match found!
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_23_16
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_23_18
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_23_19
# Match found!
# ...

# %% [markdown]
# ### Corrections for 2018-08-17 03:00-04:00
#
# I decided not to double-type all the corrections anymore !! The entries to be corrected are below.

# %%
annotation_20180817_0300_0400 = os.path.join(individual_call_annotation_folder, 
                                             'Audio Annotation Datasheet_3-4_16.08.18_corrected(1).csv')
annots_20180817_03_04 = pd.read_csv(annotation_20180817_0300_0400)

# %%
extract_single_calls_from_annotations(annots_20180817_03_04, raw_audio_folder,
                                  save_to=destination_audio_folder+'/2018-08-17 0300-0400/',
                                  save_channels=[0])
# Out:
# Match found!
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_34_3
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_34_4
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_34_10
# Match found!
# Match found!
# Match found!
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_34_21
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_34_23
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_34_24
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_34_27
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_34_31
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_34_34
# Match found!
# Match found!
# Match found!
# Could not save call!
# ...

# %%
for i, each in annots_20180817_03_04.iterrows():
    if '34_171'  in each['audio_annotation_file']:
        print(each)
# Out:
# audio_annotation_file     matching_annotaudio_Aditya_2018-08-17_34_171
# Unnamed: 1                                                        0.93
# start_random_point                                                  93
# search_start_time(s)                                            5.0592
# Direction                                                            R
# No._of_ms_whole_screen                                              45
# call_start_time                                                  2.179
# call_end_time                                                    2.219
# SNR(dB RMS)                                                      25.61
# Silent_period_Start                                              2.231
# Silent_period_end                                                 2.24
# Comments                                                           NaN
# Unnamed: 12                                                        NaN
# ...

# %%
ids_20180817_0300_0400_to_be_corrected = {'matching_annotaudio_Aditya_2018-08-17_34_12':{'call_end_time':0.084},
                          'matching_annotaudio_Aditya_2018-08-17_34_22':{'call_end_time':0.550},
                          'matching_annotaudio_Aditya_2018-08-17_34_41':{'call_end_time':0.353},
                          'matching_annotaudio_Aditya_2018-08-17_34_53':{'call_start_time':1.686,
                                                                         'call_end_time':1.715},
                          'matching_annotaudio_Aditya_2018-08-17_34_54':{'call_end_time':0.055},
                           
                          'matching_annotaudio_Aditya_2018-08-17_34_56':{'call_start_time':2.311,
                                                                          'call_end_time':2.337},
                          'matching_annotaudio_Aditya_2018-08-17_34_72':{'call_start_time':0.177},
                          'matching_annotaudio_Aditya_2018-08-17_34_81':{'call_end_time':0.189},
                          'matching_annotaudio_Aditya_2018-08-17_34_142':{'call_start_time':0.121,
                                                                         'call_end_time':0.149},
                          'matching_annotaudio_Aditya_2018-08-17_34_151':{'call_start_time':0.074,
                                                                         'call_end_time':0.098},
                          'matching_annotaudio_Aditya_2018-08-17_34_165':{'call_end_time':2.059},
                           'matching_annotaudio_Aditya_2018-08-17_34_171':{'call_end_time':2.220},
                          }

# %% [markdown]
# ### 2018-08-17 04:00-05:00

# %%
annotation_20180817_0400_0500 = os.path.join(individual_call_annotation_folder, 
                                             '2018-08-17_45_am_Aditya.csv')
annots_20180817_04_05 = pd.read_csv(annotation_20180817_0400_0500)

# %%
sum(~pd.isna(annots_20180817_04_05['call_start_time']))
# Out:
# 40

# %%
extract_single_calls_from_annotations(annots_20180817_04_05, raw_audio_folder,
                                  save_to=destination_audio_folder+'/2018-08-17_0400-0500',
                                  save_channels=[0])
# Out:
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_45_2
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_45_3
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_45_4
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_45_5
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_45_8
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_45_9
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_45_10
# Match found!
# Match found!
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_45_26
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_45_27
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_45_28
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_45_31
# ...

# %%
corrections_20180817_45 = {'matching_annotaudio_Aditya_2018-08-17_45_25':{'call_start_time':2.690,
                                                                          'call_end_time':2.725},
                           'matching_annotaudio_Aditya_2018-08-17_45_124':{'call_end_time':0.194},
                           'matching_annotaudio_Aditya_2018-08-17_45_126':{'call_start_time':0.398},
                           'matching_annotaudio_Aditya_2018-08-17_45_127':{'call_start_time':2.005,
                                                                         'call_end_time':2.022},
                           'matching_annotaudio_Aditya_2018-08-17_45_141':{'call_end_time':0.166},
                           'matching_annotaudio_Aditya_2018-08-17_45_164':{'call_end_time':3.281},
                           'matching_annotaudio_Aditya_2018-08-17_45_203':{'call_start_time':0.262},
                           'matching_annotaudio_Aditya_2018-08-17_45_267':{'call_start_time':1.150,
                                                                         'call_end_time':1.171},
                           'matching_annotaudio_Aditya_2018-08-17_45_326':{
                                                                         'call_end_time':0.320},
                           
                           'matching_annotaudio_Aditya_2018-08-17_45_340':{
                                                                         'call_end_time':1.222},
                           'matching_annotaudio_Aditya_2018-08-17_45_342':{'call_end_time':1.833},                           
                          }

# %% [markdown]
# ### Corrections for 2018-08-17 05:00-06:00

# %%
annotation_20180817_0500_0600 = os.path.join(individual_call_annotation_folder, 
                                             'Audio Annotation Datasheet_2018-08-17__5_6am.csv')
annots_20180817_05_06 = pd.read_csv(annotation_20180817_0500_0600)

# %%
extract_single_calls_from_annotations(annots_20180817_05_06, raw_audio_folder,
                                  save_to=destination_audio_folder+'/2018-08-17_0500-0600',
                                  save_channels=[0])
# Out:
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_56_2
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_56_4
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_56_5
# Match found!
# Match found!
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_56_10
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_56_12
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_56_13
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_56_14
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_56_15
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_56_16
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_56_17
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-17_56_18
# ...

# %% [markdown]
# ### ------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 2018-08-19 01:20-02:00

# %% [markdown]
# ### Notes/Corrections for 2018-08-19 01:20-02:00
#
# * matching_annotaudio_Aditya_2018-08-19_0120-0200_117 : There's nothing in this particular segment - and it is really long (~6 seconds). Need to get a clarification from Aditya
#
#
# ### Annotations to be removed/specially noted for later analysis:
#
# * matching_annotaudio_Aditya_2018-08-19_0120-0200_126 : *R. ferrumequinum* calls in the annotation. This annotation must not be considered in further steps - and should be deleted.

# %%
# 2018-08-19 01:20-02:00 matched audio annotations 
annotation_20180819_0120_0200 = os.path.join(individual_call_annotation_folder, 
                                             'Audio Annotation Datasheet_2018-08-19_120_2_am.csv')
annots_20180819_0120_0200 = pd.read_csv(annotation_20180819_0120_0200)

# %%
annots_20180819_0120_0200
# Out:
#                                 audio_annotation_file  start_random_point  \
# 0   matching_annotaudio_Aditya_2018-08-19_0120-0200_1                0.52
# 1   matching_annotaudio_Aditya_2018-08-19_0120-0200_2                0.60
# 2   matching_annotaudio_Aditya_2018-08-19_0120-0200_3                0.83
# 3   matching_annotaudio_Aditya_2018-08-19_0120-0200_6                0.22
# 4   matching_annotaudio_Aditya_2018-08-19_0120-0200_7                0.88
# 5   matching_annotaudio_Aditya_2018-08-19_0120-0200_8                0.86
# 6   matching_annotaudio_Aditya_2018-08-19_0120-020...                0.50
# 7   matching_annotaudio_Aditya_2018-08-19_0120-020...                0.32
# 8   matching_annotaudio_Aditya_2018-08-19_0120-020...                0.22
# 9   matching_annotaudio_Aditya_2018-08-19_0120-020...                0.23
# 10  matching_annotaudio_Aditya_2018-08-19_0120-020...                0.82
# 11  matching_annotaudio_Aditya_2018-08-19_0120-020...                0.09
# ...

# %%
sum(~pd.isna(annots_20180819_0120_0200['call_start_time']))
# Out:
# 39

# %%
extract_single_calls_from_annotations(annots_20180819_0120_0200, raw_audio_folder,
                                  save_to=destination_audio_folder+'/2018-08-19_0120-0200',
                                  save_channels=[0])
# Out:
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_0120-0200_1
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_0120-0200_2
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_0120-0200_3
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_0120-0200_6
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_0120-0200_7
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_0120-0200_8
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_0120-0200_13
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_0120-0200_14
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_0120-0200_15
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_0120-0200_16
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_0120-0200_18
# ...

# %%
show_annotation_row(annots_20180819_0120_0200, '0120-0200_124')
# Out:
# audio_annotation_file     matching_annotaudio_Aditya_2018-08-19_0120-020...
# start_random_point                                                     0.37
# search_start_time(s)                                                 0.5476
# Direction                                                                 L
# No._of_ms_whole_screen                                                   45
# call_start_time                                                       0.484
# call_end_time                                                         0.503
# SNR(dB RMS)                                                           29.74
# Silent_period_Start                                                    0.47
# Silent_period_end                                                     0.478
# Comments                                                                NaN
# Name: 88, dtype: object

# %%
ids_20180819_0120_0200_to_be_corrected = {
                        'matching_annotaudio_Aditya_2018-08-19_0120-0200_72' : {'call_start_time':0.445,
                                                                                'call_end_time':0.469}
                        'matching_annotaudio_Aditya_2018-08-19_0120-0200_107' :{'call_start_time':0.356},
                        'matching_annotaudio_Aditya_2018-08-19_0120-0200_109' : {'call_start_time':0.523},
                        _117
                        'matching_annotaudio_Aditya_2018-08-19_0120-0200_124' : {'call_start_time':0.483,
                                                                                'call_end_time':0.504},
                        
                        }
# Out:
#   File "<ipython-input-35-32864652ac47>", line 4
#     'matching_annotaudio_Aditya_2018-08-19_0120-0200_107' :{'call_start_time':0.356},
#                                                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 2018-08-19 02:00-03:00

# %%
# 2018-08-19 02:00-03:00 matched audio annotations 
annotation_20180819_0200_0300 = os.path.join(individual_call_annotation_folder, 
                                             'Audio Annotation Datasheet_2018-08-19_23_am.csv')
annots_20180819_0200_0300 = pd.read_csv(annotation_20180819_0200_0300)

# %%
extract_single_calls_from_annotations(annots_20180819_0200_0300, raw_audio_folder,
                                  save_to=destination_audio_folder+'/2018-08-19_0200-0300/',
                                  save_channels=[0])
# Out:
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_23_3
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_23_4
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_23_6
# Match found!
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_23_15
# Match found!
# Match found!
# Match found!
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_23_29
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_23_30
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_23_31
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_23_32
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_23_33
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-19_23_34
# Match found!
# Could not save call!
# ...

# %% [markdown]
# ### Corrections for 2018-08-19 02:00-03:00
# There were only a few annotations from which single calls could be extracted:
#
# ### Changes to be made:
#
# * __matching_annotaudio_Aditya_2018-08-19_23_16__ : call start time to 0.340
# * __matching_annotaudio_Aditya_2018-08-19_23_19__ : call start time to 0.425

# %%
for i, each in annots.iterrows():
    if '23_39'  in each['audio_annotation_file']:
        print(each)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-30794fbccf6e> in <module>()
# ----> 1 for i, each in annots.iterrows():
#       2     if '23_39'  in each['audio_annotation_file']:
#       3         print(each)
#
# NameError: name 'annots' is not defined

# %%
ids_to_be_corrected = {
    'matching_annotaudio_Aditya_2018-08-19_23_16' : {'call_start_time':0.340},
    'matching_annotaudio_Aditya_2018-08-19_23_19' : {'call_start_time':0.425}  
                    }

# %% [markdown]
# ### 2018-08-20 0111-0200?

# %% [markdown]
# ### 2018-08-20 0200-0300

# %%
annotation_20180820_0200_0300 = os.path.join(individual_call_annotation_folder, 
                                             'Audio Annotation Datasheet_2018-08-20_2_3_am.csv')
annots_20180820_0200_0300 = pd.read_csv(annotation_20180820_0200_0300)
annots_20180820_0200_0300.head()
# Out:
#                                audio_annotation_file  start_random_point  \
# 0  matching_annotaudio_Aditya_2018-08-20_0200-0300_2                0.17
# 1  matching_annotaudio_Aditya_2018-08-20_0200-0300_3                0.14
# 2  matching_annotaudio_Aditya_2018-08-20_0200-0300_5                0.16
# 3  matching_annotaudio_Aditya_2018-08-20_0200-0300_6                0.69
# 4  matching_annotaudio_Aditya_2018-08-20_0200-0300_7                0.61
#
#    search_start_time(s) Direction  No._of_ms_whole_screen  call_start_time  \
# 0                   NaN         R                     NaN              NaN
# 1                   NaN         L                     NaN              NaN
# 2                   NaN         R                     NaN              NaN
# 3                   NaN         R                     NaN              NaN
# 4                   NaN         L                     NaN              NaN
#
#    call_end_time  SNR(dB RMS)  Silent_period_Start  Silent_period_end  \
# ...

# %%
show_number_of_valid_call_annotations(annots_20180820_0200_0300)
# Out:
# 21

# %%
extract_single_calls_from_annotations(annots_20180820_0200_0300, raw_audio_folder,
                                  save_to=destination_audio_folder+'/2018-08-20_0200-0300/',
                                  save_channels=[0])
# Out:
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-20_0200-0300_2
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-20_0200-0300_3
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-20_0200-0300_5
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-20_0200-0300_6
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-20_0200-0300_7
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-20_0200-0300_8
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-20_0200-0300_13
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-20_0200-0300_17
# Match found!
# Match found!
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-20_0200-0300_24
# Match found!
# Could not save call!
# matching_annotaudio_Aditya_2018-08-20_0200-0300_26
# Match found!
# ...

# %%
show_annotation_row(annots_20180820_0200_0300, '0200-0300_92')
# Out:
# audio_annotation_file     matching_annotaudio_Aditya_2018-08-20_0200-030...
# start_random_point                                                     0.53
# search_start_time(s)                                                 3.6464
# Direction                                                                 R
# No._of_ms_whole_screen                                                   55
# call_start_time                                                       1.974
# call_end_time                                                         1.988
# SNR(dB RMS)                                                           27.66
# Silent_period_Start                                                   1.992
# Silent_period_end                                                     1.995
# Comments                                                                NaN
# Name: 51, dtype: object

# %%
ids_20180820_0200_0300_to_be_corrected = {
                'matching_annotaudio_Aditya_2018-08-20_0200-0300_16':{'call_end_time':0.033},
                'matching_annotaudio_Aditya_2018-08-20_0200-0300_18':{'call_start_time':0.588},
                'matching_annotaudio_Aditya_2018-08-20_0200-0300_43':{'call_start_time':0.795,
                                                                     'call_end_time':0.817},
                'matching_annotaudio_Aditya_2018-08-20_0200-0300_64':{'call_start_time':0.695},
                'matching_annotaudio_Aditya_2018-08-20_0200-0300_71':{'call_start_time':0.034},
                'matching_annotaudio_Aditya_2018-08-20_0200-0300_73:'{'call_start_time':0.027,
                                                                      'call_end_time':0.049},
                'matching_annotaudio_Aditya_2018-08-20_0200-0300_90':{'call_end_time':0.051},
                'matching_annotaudio_Aditya_2018-08-20_0200-0300_92':{'call_end_time':1.989}   
                
                                            }
# Out:
#   File "<ipython-input-44-39d759449ccc>", line 8
#     'matching_annotaudio_Aditya_2018-08-20_0200-0300_73:'{'call_start_time':0.027,
#                                                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 2018-08-20 0300-0400

# %%
# 2018-08-20 03:00-04:00 matched audio annotations 
annotation_20180820_0300_0400 = os.path.join(individual_call_annotation_folder, 
                                             'Audio Annotation Datasheet_2018-08-20_3_4_am.csv')
annots_20180820_0300_0400 = pd.read_csv(annotation_20180820_0300_0400)
annots_20180820_0300_0400.head()
# Out:
#                                audio_annotation_file  start_random_point  \
# 0  matching_annotaudio_Aditya_2018-08-20_0300-0400_1                0.55
# 1  matching_annotaudio_Aditya_2018-08-20_0300-0400_6                0.97
# 2  matching_annotaudio_Aditya_2018-08-20_0300-0400_9                0.79
# 3  matching_annotaudio_Aditya_2018-08-20_0300-040...                0.11
# 4  matching_annotaudio_Aditya_2018-08-20_0300-040...                0.51
#
#    search_start_time(s) Direction  No._of_ms_whole_screen  call_start_time  \
# 0                   NaN         R                     NaN              NaN
# 1                   NaN         R                     NaN              NaN
# 2                   NaN         L                     NaN              NaN
# 3                   NaN         R                     NaN              NaN
# 4                   NaN         L                     NaN              NaN
#
#    call_end_time  SNR(dB RMS)  Silent_period_Start  Silent_period_end  \
# ...

# %%
show_number_of_valid_call_annotations(annots_20180820_0300_0400)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-848d170cb3ef> in <module>()
# ----> 1 show_number_of_valid_call_annotations(annots_20180820_0300_0400)
#
# NameError: name 'annots_20180820_0300_0400' is not defined

# %%
extract_single_calls_from_annotations(annots_20180820_0300_0400, raw_audio_folder,
                                  save_to=destination_audio_folder+'/2018-08-20_0300-0400/',
                                  save_channels=[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-cb5a5afa32a6> in <module>()
# ----> 1 extract_single_calls_from_annotations(annots_20180820_0300_0400, raw_audio_folder,
#       2                                   save_to=destination_audio_folder+'/2018-08-20_0300-0400/',
#       3                                   save_channels=[0])
#
# NameError: name 'annots_20180820_0300_0400' is not defined

# %%
show_annotation_row(annots_20180820_0300_0400, '0400_91')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-0ce541f4dac1> in <module>()
# ----> 1 show_annotation_row(annots_20180820_0300_0400, '0400_91')
#
# NameError: name 'annots_20180820_0300_0400' is not defined

# %%
ids_20180820_0300_0400_to_be_corrected={
                    'matching_annotaudio_Aditya_20180820_0300_0400_18' : {'call_end_time':0.499},
                    'matching_annotaudio_Aditya_20180820_0300_0400_61' : {'call_start_time':0.353,
                                                                           'call_end_time':0.372},
                    'matching_annotaudio_Aditya_20180820_0300_0400_91' : {'call_start_time':0.156},
                                        }
